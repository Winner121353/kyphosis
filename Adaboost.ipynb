# %% [markdown]
# <a href="https://colab.research.google.com/github/Winner121353/kyphosis/blob/master/Adaboost.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %pylab inline
import numpy as np
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
SAMPLE_NUM_PER_CLASS = 200
rng = np.random.RandomState(0)
X0 = rng.randn(SAMPLE_NUM_PER_CLASS,2) * 0.15
X1_a = rng.randn(SAMPLE_NUM_PER_CLASS)*2*np.pi
X1_r = rng.randn(SAMPLE_NUM_PER_CLASS) * 0.2+0.4
X1 = np.asarray([np.cos(X1_a)*X1_r,np.sin(X1_a)*X1_r]).T
X = np.concatenate((X0,X1),axis=0)
y = np.concatenate((np.zeros(SAMPLE_NUM_PER_CLASS),np.ones(SAMPLE_NUM_PER_CLASS)),axis=0)

# %%
scatter(X[:, 0],X[:, 1],c=y,s=32,cmap = 'summer')

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30)

# %%
from sklearn.ensemble import AdaBoostClassifier

# %%
m = AdaBoostClassifier(n_estimators=50)

# %%
m.fit(X_train,y_train)
# Out:
# AdaBoostClassifier(algorithm='SAMME.R', base_estimator=None,
#           learning_rate=1.0, n_estimators=50, random_state=None)

# %%
predictions = m.predict(X_test)

# %%
from sklearn.metrics import classification_report,confusion_matrix

# %%
print(classification_report(y_test,predictions))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.70      0.65      0.67        62
#          1.0       0.65      0.71      0.68        58
#
#    micro avg       0.68      0.68      0.68       120
#    macro avg       0.68      0.68      0.67       120
# weighted avg       0.68      0.68      0.67       120

# %%
print(confusion_matrix(y_test,predictions))
# Out:
# [[40 22]
#  [17 41]]
